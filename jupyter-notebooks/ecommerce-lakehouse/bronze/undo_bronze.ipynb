# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("general").getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ba7b2bbb9aec:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>general</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.sql("show tables in bronze").show()
# Out:
# +---------+-----------------+-----------+
# |namespace|        tableName|isTemporary|
# +---------+-----------------+-----------+
# |   bronze|raw_customer_feed|      false|
# +---------+-----------------+-----------+

# %%
spark.sql("drop table if exists bronze.raw_customer_feed")
spark.sql("drop table if exists bronze.customer")
spark.sql("drop table if exists bronze.customer_address")
spark.sql("drop table if exists bronze.raw_product_feed")
spark.sql("drop table if exists bronze.product")
spark.sql("drop table if exists bronze.product_price")
spark.sql("drop table if exists bronze.fact_orders")
spark.sql("drop table if exists bronze.fact_payments")
spark.sql("drop table if exists bronze.fact_inventory")
spark.sql("drop table if exists bronze.fact_ads_performance")
spark.sql("drop table if exists bronze.fact_customer_events")
# Out:
# DataFrame[]

# %%
spark.sql("show tables in bronze").show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# +---------+---------+-----------+

# %%
spark.sql("select * from gold.load_controller").show()
# Out:
# +-----+-----------+----------+---------+----------+--------------+-----------+------------+----------+----------+-----------+-----------+
# |layer|schema_name|table_name|load_type|write_mode|load_timestamp|load_status|loaded_count|created_on|created_by|modified_on|modified_by|
# +-----+-----------+----------+---------+----------+--------------+-----------+------------+----------+----------+-----------+-----------+
# +-----+-----------+----------+---------+----------+--------------+-----------+------------+----------+----------+-----------+-----------+

# %%
from utils.load_controller import truncate_control_logs

var = truncate_control_logs(spark)

# %%
spark.sql("select * from gold.load_controller").show()
# Out:
# +-----+-----------+----------+---------+----------+--------------+-----------+------------+----------+----------+-----------+-----------+
# |layer|schema_name|table_name|load_type|write_mode|load_timestamp|load_status|loaded_count|created_on|created_by|modified_on|modified_by|
# +-----+-----------+----------+---------+----------+--------------+-----------+------------+----------+----------+-----------+-----------+
# +-----+-----------+----------+---------+----------+--------------+-----------+------------+----------+----------+-----------+-----------+

# %%
spark.stop()
