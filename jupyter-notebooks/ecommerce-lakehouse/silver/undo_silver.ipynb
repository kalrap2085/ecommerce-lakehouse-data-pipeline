# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("general").getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://5c21ee288d65:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>general</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.sql("show tables in silver").show()
# Out:
# +---------+--------------------+-----------+
# |namespace|           tableName|isTemporary|
# +---------+--------------------+-----------+
# |   silver|            customer|      false|
# |   silver|    customer_address|      false|
# |   silver|fact_ads_performance|      false|
# |   silver|fact_customer_events|      false|
# |   silver|      fact_inventory|      false|
# |   silver|         fact_orders|      false|
# |   silver|       fact_payments|      false|
# |   silver|             product|      false|
# |   silver|       product_price|      false|
# +---------+--------------------+-----------+

# %%
spark.sql("drop table if exists silver.customer")
spark.sql("drop table if exists silver.customer_address")
spark.sql("drop table if exists silver.product")
spark.sql("drop table if exists silver.product_price")
spark.sql("drop table if exists silver.fact_orders")
spark.sql("drop table if exists silver.fact_payments")
spark.sql("drop table if exists silver.fact_inventory")
spark.sql("drop table if exists silver.fact_ads_performance")
spark.sql("drop table if exists silver.fact_customer_events")
# Out:
# DataFrame[]

# %%
spark.sql("select * from gold.load_controller").show()
# Out:
# +-----+-----------+----------+---------+----------+--------------+-----------+------------+----------+----------+-----------+-----------+
# |layer|schema_name|table_name|load_type|write_mode|load_timestamp|load_status|loaded_count|created_on|created_by|modified_on|modified_by|
# +-----+-----------+----------+---------+----------+--------------+-----------+------------+----------+----------+-----------+-----------+
# +-----+-----------+----------+---------+----------+--------------+-----------+------------+----------+----------+-----------+-----------+

# %%
spark.stop()
